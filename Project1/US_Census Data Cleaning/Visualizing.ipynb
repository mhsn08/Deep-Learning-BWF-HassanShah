# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Refined_Data.csv")
df.dtypes
# Out:
# Unnamed: 0      int64
# State          object
# TotalPop        int64
# Hispanic      float64
# White         float64
# Black         float64
# Native        float64
# Asian         float64
# Pacific       float64
# Income        float64
# males           int64
# females         int64
# dtype: object

# %%
df.head()
# Out:
#    Unnamed: 0       State  TotalPop   Hispanic      White      Black  \
# 0           0     Alabama   4830620   3.751616  61.878656  31.252976
# 1           1      Alaska    733375   5.909581  60.910180   2.848503
# 2           2     Arizona   6641928  29.565921  57.120000   3.850987
# 3           3    Arkansas   2958208   6.215474  71.137810  18.968759
# 4           4  California  38421464  37.291875  40.215789   5.677396
#
#       Native      Asian   Pacific        Income     males   females
# 0   0.453231   1.050255  0.034354  43296.358603   2341093   2489527
# 1  16.391018   5.450299  1.058683  70354.743902    384160    349215
# 2   4.355066   2.876579  0.167632  54207.820955   3299088   3342840
# 3   0.522920   1.142336  0.146861  41935.633968   1451913   1506295
# 4   0.405292  13.052234  0.351410  67264.782303  19087135  19334329

# %%
plt.scatter(df["Income"],df["females"])
plt.show()

# %%
# I already handled NULL Values so no error ;). I replaced those values with 0 in that data. Now replaceing it
# with what makes sense

# %%
df['females'] = df['females'].mask(df['females'] == 0, df['TotalPop'] - df['males'])

# %%
df
# Out:
#     Unnamed: 0                 State  TotalPop   Hispanic      White  \
# 0            0               Alabama   4830620   3.751616  61.878656
# 1            1                Alaska    733375   5.909581  60.910180
# 2            2               Arizona   6641928  29.565921  57.120000
# 3            3              Arkansas   2958208   6.215474  71.137810
# 4            4            California  38421464  37.291875  40.215789
# 5            5              Colorado   5278906  20.784380  69.895572
# 6            1           Connecticut   3593222  15.604831  67.677053
# 7            2              Delaware    926454   8.824766  64.632710
# 8            3  District of Columbia    647484   9.165922  33.103911
# 9            4               Florida  19645772  21.338543  59.083749
# 10           5               Georgia  10006693   8.418242  54.286306
# 11           1                Hawaii   1406299   9.186709  25.032278
# 12           2                 Idaho   1616547  11.505369  83.136242
# ...

# %%
# All females Column Filled

# %%
plt.scatter(df["Income"],df["females"])
plt.show()

# %%
df.head()
# Out:
#    Unnamed: 0       State  TotalPop   Hispanic      White      Black  \
# 0           0     Alabama   4830620   3.751616  61.878656  31.252976
# 1           1      Alaska    733375   5.909581  60.910180   2.848503
# 2           2     Arizona   6641928  29.565921  57.120000   3.850987
# 3           3    Arkansas   2958208   6.215474  71.137810  18.968759
# 4           4  California  38421464  37.291875  40.215789   5.677396
#
#       Native      Asian   Pacific        Income     males   females
# 0   0.453231   1.050255  0.034354  43296.358603   2341093   2489527
# 1  16.391018   5.450299  1.058683  70354.743902    384160    349215
# 2   4.355066   2.876579  0.167632  54207.820955   3299088   3342840
# 3   0.522920   1.142336  0.146861  41935.633968   1451913   1506295
# 4   0.405292  13.052234  0.351410  67264.782303  19087135  19334329

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# State         0
# TotalPop      0
# Hispanic      0
# White         0
# Black         0
# Native        0
# Asian         0
# Pacific       4
# Income        0
# males         0
# females       0
# dtype: int64

# %%
df['Pacific'].fillna(100 - (df['Hispanic'] + df['White'] + df['Black'] + df['Native'] + df['Asian']), inplace=True)

# %%
df
# Out:
#     Unnamed: 0                 State  TotalPop   Hispanic      White  \
# 0            0               Alabama   4830620   3.751616  61.878656
# 1            1                Alaska    733375   5.909581  60.910180
# 2            2               Arizona   6641928  29.565921  57.120000
# 3            3              Arkansas   2958208   6.215474  71.137810
# 4            4            California  38421464  37.291875  40.215789
# 5            5              Colorado   5278906  20.784380  69.895572
# 6            1           Connecticut   3593222  15.604831  67.677053
# 7            2              Delaware    926454   8.824766  64.632710
# 8            3  District of Columbia    647484   9.165922  33.103911
# 9            4               Florida  19645772  21.338543  59.083749
# 10           5               Georgia  10006693   8.418242  54.286306
# 11           1                Hawaii   1406299   9.186709  25.032278
# 12           2                 Idaho   1616547  11.505369  83.136242
# ...

# %%
df.to_csv("FinalData.csv")

# %%
df['White'].plot.hist(bins=10)

plt.title('Histogram For White People')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['Black'].plot.hist(bins=10)

plt.title('Histogram For Black People')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['Native'].plot.hist(bins=10)

plt.title('Histogram For White People')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['Asian'].plot.hist(bins=10)

plt.title('Histogram For Asian People')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['Pacific'].plot.hist(bins=10)

plt.title('Histogram For White People')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['Hispanic'].plot.hist(bins=10)

plt.title('Histogram For Hispanic People')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
