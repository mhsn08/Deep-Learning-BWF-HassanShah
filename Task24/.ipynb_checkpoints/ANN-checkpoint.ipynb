# %%
import numpy as np
import pandas as pd
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Data preprocessed through libraries

# %%
at = pd.read_csv('Attack_types.txt',sep=' ')
df = pd.read_csv('Dataset.txt', sep=",")
df = pd.merge(df,at,on="attack_category",how="left")
df['attack_type'] = df['attack_type'].fillna('others')
df.loc[df['attack_category'] == 'normal', 'attack_type'] = 'normal'
df.drop_duplicates(subset=None, keep='first', inplace=True)
df = df.drop('attack_category',axis=1)

le = LabelEncoder()
df['attack_type'] = le.fit_transform(df['attack_type'])
df['protocol_type'] = le.fit_transform(df['protocol_type'])

label = df.pop('attack_type')

selector = VarianceThreshold(threshold=0.9)

df = df.apply(pd.to_numeric, errors='coerce')

selector.fit(df)

refined_data = selector.transform(df)

selected_indices = selector.get_support(indices=True)

refined_df = df.iloc[:, selected_indices]

df = refined_df


X = df
y = label

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

clf = MLPClassifier(hidden_layer_sizes=(100, ), activation='relu', solver='adam', max_iter=200)

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(classification_report(y_test, y_pred))
print(accuracy)
# Out:
# /home/h/anaconda3/lib/python3.9/site-packages/sklearn/feature_selection/_variance_threshold.py:111: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   self.variances_ = np.nanvar(X, axis=0)
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95      9198
#            1       0.97      0.97      0.97     13512
#            2       0.78      0.79      0.78      2291
#            3       0.00      0.00      0.00       180
#            4       0.06      0.07      0.06        14
#
#     accuracy                           0.94     25195
#    macro avg       0.55      0.56      0.55     25195
# weighted avg       0.93      0.94      0.94     25195
#
# 0.9410994244889859

# %%
df
# Out:
#         duration  protocol_type  hot  logged_in  num_compromised  num_root  \
# 0              0              1    0          0                0         0
# 1              0              2    0          0                0         0
# 2              0              1    0          0                0         0
# 3              0              1    0          1                0         0
# 4              0              1    0          1                0         0
# ...          ...            ...  ...        ...              ...       ...
# 125843         0              1    0          0                0         0
# 125844         8              2    0          0                0         0
# 125845         0              1    0          1                0         0
# 125846         0              1    0          0                0         0
# 125847         0              1    0          1                0         0
#
# ...

# %%
clf = MLPClassifier(hidden_layer_sizes=(100, ), activation='relu', solver='sgd', max_iter=200)

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(classification_report(y_test, y_pred))
print(accuracy)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.90      0.93      9247
#            1       0.90      0.99      0.95     13417
#            2       0.91      0.69      0.79      2339
#            3       1.00      0.01      0.02       183
#            4       0.00      0.00      0.00         9
#
#     accuracy                           0.92     25195
#    macro avg       0.75      0.52      0.54     25195
# weighted avg       0.93      0.92      0.92     25195
#
# 0.9233974995038698
# /home/h/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
clf = MLPClassifier(hidden_layer_sizes=(100, ), activation='relu', solver='sgd', max_iter=300)

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(classification_report(y_test, y_pred))
print(accuracy)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.90      0.93      9247
#            1       0.90      1.00      0.95     13417
#            2       0.94      0.68      0.79      2339
#            3       1.00      0.01      0.02       183
#            4       0.00      0.00      0.00         9
#
#     accuracy                           0.92     25195
#    macro avg       0.76      0.52      0.54     25195
# weighted avg       0.93      0.92      0.92     25195
#
# 0.9225243103790435
# /home/h/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
clf = MLPClassifier(hidden_layer_sizes=(100, ), activation='relu', solver='adam', max_iter=300)

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(classification_report(y_test, y_pred))
print(accuracy)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.94      9247
#            1       0.96      0.97      0.97     13417
#            2       0.85      0.79      0.82      2339
#            3       0.76      0.54      0.63       183
#            4       0.00      0.00      0.00         9
#
#     accuracy                           0.94     25195
#    macro avg       0.70      0.65      0.67     25195
# weighted avg       0.94      0.94      0.94     25195
#
# 0.9436396110339353
# /home/h/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
clf = MLPClassifier(hidden_layer_sizes=(100,50), activation='relu', solver='adam', max_iter=200)

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(classification_report(y_test, y_pred))
print(accuracy)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95      9247
#            1       0.97      0.98      0.97     13417
#            2       0.76      0.84      0.80      2339
#            3       0.61      0.30      0.40       183
#            4       0.00      0.00      0.00         9
#
#     accuracy                           0.95     25195
#    macro avg       0.66      0.61      0.62     25195
# weighted avg       0.95      0.95      0.94     25195
#
# 0.945385989283588

# %%
clf = MLPClassifier(hidden_layer_sizes=(100,100), activation='relu', solver='adam', max_iter=200)

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(classification_report(y_test, y_pred))
print(accuracy)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95      9247
#            1       0.98      0.96      0.97     13417
#            2       0.79      0.90      0.85      2339
#            3       0.12      0.18      0.14       183
#            4       0.00      0.00      0.00         9
#
#     accuracy                           0.94     25195
#    macro avg       0.57      0.60      0.58     25195
# weighted avg       0.95      0.94      0.95     25195
#
# 0.9429251835681682

# %%
clf = MLPClassifier(hidden_layer_sizes=(100,100,50), activation='relu', solver='adam', max_iter=300)

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(classification_report(y_test, y_pred))
print(accuracy)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96      9247
#            1       0.94      0.99      0.97     13417
#            2       0.94      0.73      0.82      2339
#            3       0.64      0.26      0.37       183
#            4       0.00      0.00      0.00         9
#
#     accuracy                           0.95     25195
#    macro avg       0.70      0.59      0.63     25195
# weighted avg       0.95      0.95      0.95     25195
#
# 0.9519745981345505
# /home/h/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# # Data Manually pre-processed

# %%
df = pd.read_csv('Refined.csv')

# le = LabelEncoder()
# df['attack_type'] = le.fit_transform(df['attack_type'])
# df['protocol_type'] = le.fit_transform(df['protocol_type'])

label = df.pop('attack_type')

# selector = VarianceThreshold(threshold=0.1)

# df = df.apply(pd.to_numeric, errors='coerce')

# selector.fit(df)

# refined_data = selector.transform(df)

# selected_indices = selector.get_support(indices=True)

# refined_df = df.iloc[:, selected_indices]

# df = refined_df


X = df
y = label

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

clf = MLPClassifier(hidden_layer_sizes=(100, ), activation='relu', solver='adam', max_iter=200)

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(classification_report(y_test, y_pred))
print(accuracy)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.99      0.91     13406
#            1       0.99      0.86      0.92      9257
#            2       0.34      0.18      0.23       186
#            3       0.73      0.36      0.48      2309
#            4       0.00      0.00      0.00        12
#
#     accuracy                           0.88     25170
#    macro avg       0.58      0.48      0.51     25170
# weighted avg       0.88      0.88      0.87     25170
#
# 0.877989670242352
# /home/h/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
clf = MLPClassifier(hidden_layer_sizes=(100,100,50), activation='relu', solver='adam', max_iter=200)

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(classification_report(y_test, y_pred))
print(accuracy)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.92     13406
#            1       0.88      0.98      0.93      9257
#            2       0.00      0.00      0.00       186
#            3       0.65      0.31      0.42      2309
#            4       0.00      0.00      0.00        12
#
#     accuracy                           0.89     25170
#    macro avg       0.49      0.44      0.45     25170
# weighted avg       0.87      0.89      0.87     25170
#
# 0.8872467222884386
# /home/h/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# # Unprocessed Data

# %%
at = pd.read_csv('Attack_types.txt',sep=' ')
df = pd.read_csv('Dataset.txt', sep=",")
df = pd.merge(df,at,on="attack_category",how="left")
df['attack_type'] = df['attack_type'].fillna('others')
df.loc[df['attack_category'] == 'normal', 'attack_type'] = 'normal'
df.drop_duplicates(subset=None, keep='first', inplace=True)
df = df.drop('attack_category',axis=1)

df['protocol_type'] = df['protocol_type'].replace('tcp',1)
df['protocol_type'] = df['protocol_type'].replace('udp',2)
df['protocol_type'] = df['protocol_type'].replace('icmp',3)

arr = df['flag'].unique()
for i in range(len(arr)):
    df['flag'] = df['flag'].replace(arr[i],i)

arr = df['attack_type'].unique()
for i in range(len(arr)):
    df['attack_type'] = df['attack_type'].replace(arr[i],i)
    
arr = df['service'].unique()
for i in range(len(arr)):
    df['service'] = df['service'].replace(arr[i],i)
    


# le = LabelEncoder()
# df['attack_type'] = le.fit_transform(df['attack_type'])
# df['protocol_type'] = le.fit_transform(df['protocol_type'])

label = df.pop('attack_type')

# selector = VarianceThreshold(threshold=0.1)

# df = df.apply(pd.to_numeric, errors='coerce')

# selector.fit(df)

# refined_data = selector.transform(df)

# selected_indices = selector.get_support(indices=True)

# refined_df = df.iloc[:, selected_indices]

# df = refined_df


X = df
y = label

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

clf = MLPClassifier(hidden_layer_sizes=(100, ), activation='relu', solver='adam', max_iter=200)

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(classification_report(y_test, y_pred))
print(accuracy)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96     13451
#            1       0.99      0.98      0.99      9175
#            2       0.18      0.35      0.24       200
#            3       0.92      0.89      0.91      2363
#            4       0.00      0.00      0.00         6
#
#     accuracy                           0.96     25195
#    macro avg       0.61      0.64      0.62     25195
# weighted avg       0.96      0.96      0.96     25195
#
# 0.9567771383210955
# /home/h/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
clf = MLPClassifier(hidden_layer_sizes=(100,100,50), activation='relu', solver='adam', max_iter=200)

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(classification_report(y_test, y_pred))
print(accuracy)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97     13451
#            1       0.99      0.99      0.99      9175
#            2       0.06      0.04      0.04       200
#            3       0.92      0.92      0.92      2363
#            4       0.00      0.00      0.00         6
#
#     accuracy                           0.97     25195
#    macro avg       0.59      0.58      0.59     25195
# weighted avg       0.96      0.97      0.97     25195
#
# 0.9680095256995436
# /home/h/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
clf = MLPClassifier(hidden_layer_sizes=(100,100,50), activation='relu', solver='adam', max_iter=200)

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(classification_report(y_test, y_pred))
print(accuracy)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97     13451
#            1       0.98      0.98      0.98      9175
#            2       0.00      0.00      0.00       200
#            3       0.91      0.89      0.90      2363
#            4       0.00      0.00      0.00         6
#
#     accuracy                           0.96     25195
#    macro avg       0.57      0.57      0.57     25195
# weighted avg       0.95      0.96      0.96     25195
#
# 0.9610240127009327
# /home/h/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
clf = MLPClassifier(hidden_layer_sizes=(100,50,50), activation='relu', solver='adam', max_iter=200)

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(classification_report(y_test, y_pred))
print(accuracy)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96     13451
#            1       0.96      0.96      0.96      9175
#            2       0.00      0.00      0.00       200
#            3       0.83      0.86      0.84      2363
#            4       0.00      0.00      0.00         6
#
#     accuracy                           0.94     25195
#    macro avg       0.55      0.56      0.55     25195
# weighted avg       0.94      0.94      0.94     25195
#
# 0.9445524905735265
# /home/h/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
