# %%
import pandas as pd

# %%
df = pd.read_csv("titanic_train.csv")
df.head()
# Out:
#    passenger_id  pclass                                               name  \
# 0          1216       3                                 Smyth, Miss. Julia
# 1           699       3                                    Cacic, Mr. Luka
# 2          1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3           449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4           576       2                                    Veal, Mr. James
#
#       sex   age  sibsp  parch  ticket     fare cabin embarked boat  body  \
# 0  female   NaN      0      0  335432   7.7333   NaN        Q   13   NaN
# 1    male  38.0      0      0  315089   8.6625   NaN        S  NaN   NaN
# 2  female  30.0      1      1  345773  24.1500   NaN        S  NaN   NaN
# 3  female  54.0      1      3   29105  23.0000   NaN        S    4   NaN
# 4    male  40.0      0      0   28221  13.0000   NaN        S  NaN   NaN
#
#                   home.dest  survived
# 0                       NaN         1
# 1                   Croatia         0
# 2                       NaN         0
# 3      Cornwall / Akron, OH         1
# 4  Barre, Co Washington, VT         0

# %%
# Export this data to json
df.to_json('titanic.json', orient='records')

# %%
df = pd.read_json("titanic.json")
df.head()
# Out:
#    passenger_id  pclass                                               name  \
# 0          1216       3                                 Smyth, Miss. Julia
# 1           699       3                                    Cacic, Mr. Luka
# 2          1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3           449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4           576       2                                    Veal, Mr. James
#
#       sex   age  sibsp  parch  ticket     fare cabin embarked  boat  body  \
# 0  female   NaN      0      0  335432   7.7333  None        Q    13   NaN
# 1    male  38.0      0      0  315089   8.6625  None        S  None   NaN
# 2  female  30.0      1      1  345773  24.1500  None        S  None   NaN
# 3  female  54.0      1      3   29105  23.0000  None        S     4   NaN
# 4    male  40.0      0      0   28221  13.0000  None        S  None   NaN
#
#                   home.dest  survived
# 0                      None         1
# 1                   Croatia         0
# 2                      None         0
# 3      Cornwall / Akron, OH         1
# 4  Barre, Co Washington, VT         0

# %%
# Export this as Excel
df.to_excel('titanic.xlsx', index=False)
df.to_excel('titanic2.xlsx', index=True)

# %%
df = pd.read_excel('titanic.xlsx')
df.head()
# Out:
#    passenger_id  pclass                                               name  \
# 0          1216       3                                 Smyth, Miss. Julia
# 1           699       3                                    Cacic, Mr. Luka
# 2          1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3           449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4           576       2                                    Veal, Mr. James
#
#       sex   age  sibsp  parch  ticket     fare cabin embarked boat  body  \
# 0  female   NaN      0      0  335432   7.7333   NaN        Q   13   NaN
# 1    male  38.0      0      0  315089   8.6625   NaN        S  NaN   NaN
# 2  female  30.0      1      1  345773  24.1500   NaN        S  NaN   NaN
# 3  female  54.0      1      3   29105  23.0000   NaN        S    4   NaN
# 4    male  40.0      0      0   28221  13.0000   NaN        S  NaN   NaN
#
#                   home.dest  survived
# 0                       NaN         1
# 1                   Croatia         0
# 2                       NaN         0
# 3      Cornwall / Akron, OH         1
# 4  Barre, Co Washington, VT         0

# %%
df = pd.read_excel('titanic2.xlsx')
df.head()
# Out:
#    Unnamed: 0  passenger_id  pclass  \
# 0           0          1216       3
# 1           1           699       3
# 2           2          1267       3
# 3           3           449       2
# 4           4           576       2
#
#                                                 name     sex   age  sibsp  \
# 0                                 Smyth, Miss. Julia  female   NaN      0
# 1                                    Cacic, Mr. Luka    male  38.0      0
# 2  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...  female  30.0      1
# 3              Hocking, Mrs. Elizabeth (Eliza Needs)  female  54.0      1
# 4                                    Veal, Mr. James    male  40.0      0
#
#    parch  ticket     fare cabin embarked boat  body                 home.dest  \
# 0      0  335432   7.7333   NaN        Q   13   NaN                       NaN
# 1      0  315089   8.6625   NaN        S  NaN   NaN                   Croatia
# 2      1  345773  24.1500   NaN        S  NaN   NaN                       NaN
# 3      3   29105  23.0000   NaN        S    4   NaN      Cornwall / Akron, OH
# 4      0   28221  13.0000   NaN        S  NaN   NaN  Barre, Co Washington, VT
#
#    survived
# 0         1
# 1         0
# 2         0
# 3         1
# 4         0

# %%
df = pd.read_excel('titanic.xlsx')
df.head()
# Out:
#    passenger_id  pclass                                               name  \
# 0          1216       3                                 Smyth, Miss. Julia
# 1           699       3                                    Cacic, Mr. Luka
# 2          1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3           449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4           576       2                                    Veal, Mr. James
#
#       sex   age  sibsp  parch  ticket     fare cabin embarked boat  body  \
# 0  female   NaN      0      0  335432   7.7333   NaN        Q   13   NaN
# 1    male  38.0      0      0  315089   8.6625   NaN        S  NaN   NaN
# 2  female  30.0      1      1  345773  24.1500   NaN        S  NaN   NaN
# 3  female  54.0      1      3   29105  23.0000   NaN        S    4   NaN
# 4    male  40.0      0      0   28221  13.0000   NaN        S  NaN   NaN
#
#                   home.dest  survived
# 0                       NaN         1
# 1                   Croatia         0
# 2                       NaN         0
# 3      Cornwall / Akron, OH         1
# 4  Barre, Co Washington, VT         0

# %%
import sqlite3

conn = sqlite3.connect('titanic.db')
cur = conn.cursor()

df.to_sql('titanic', conn, if_exists='replace', index=False)

conn.commit()
conn.close()

# %%
conn = sqlite3.connect('titanic.db')

df = pd.read_sql('SELECT * FROM titanic', conn)

conn.close()

df.head()
# Out:
#    passenger_id  pclass                                               name  \
# 0          1216       3                                 Smyth, Miss. Julia
# 1           699       3                                    Cacic, Mr. Luka
# 2          1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3           449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4           576       2                                    Veal, Mr. James
#
#       sex   age  sibsp  parch  ticket     fare cabin embarked  boat  body  \
# 0  female   NaN      0      0  335432   7.7333  None        Q    13   NaN
# 1    male  38.0      0      0  315089   8.6625  None        S  None   NaN
# 2  female  30.0      1      1  345773  24.1500  None        S  None   NaN
# 3  female  54.0      1      3   29105  23.0000  None        S     4   NaN
# 4    male  40.0      0      0   28221  13.0000  None        S  None   NaN
#
#                   home.dest  survived
# 0                      None         1
# 1                   Croatia         0
# 2                      None         0
# 3      Cornwall / Akron, OH         1
# 4  Barre, Co Washington, VT         0
